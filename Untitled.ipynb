# %%
import numpy as np
import pandas as pd
import cv2 as cv
from skimage import io
from PIL import Image
import matplotlib.pylab as plt

# %%
image=Image.open("mitul.jpg")
image_1=Image.open("mart.jpg")

# %%
image.show()
image_1.show()

# %%
plt.imshow(image)

# %%
plt.imshow(image_1)

# %%
print(image.size)
print(image.format)
print(image.mode)
# Out:
# (1440, 1309)
# JPEG
# RGB

# %%
print(image_1.size)
print(image_1.format)
print(image_1.mode)
# Out:
# (600, 600)
# JPEG
# RGB

# %%
bw_image=image.convert('L')
plt.imshow(bw_image, cmap = 'gray')

# %%
bw_image=image_1.convert('L')
plt.imshow(bw_image, cmap = 'gray')

# %%
# Out:
# uint8
# 1309
# 1440
# 3

# %%
plt.contour(gray_image, origin = "image")

# %%
(thresh, blackAndWhiteImage) = cv.threshold(gray_image, 20, 255, cv.THRESH_BINARY)
(thresh, blackAndWhiteImage) = cv.threshold(gray_image, 80, 255, cv.THRESH_BINARY)
(thresh, blackAndWhiteImage) = cv.threshold(gray_image, 160, 255, cv.THRESH_BINARY)
(thresh, blackAndWhiteImage) = cv.threshold(gray_image, 200, 255, cv.THRESH_BINARY)
plt.imshow(blackAndWhiteImage)
plt.show()

# %%
output2 = cv.blur(gray_image, (10, 10))
plt.imshow(output2)
plt.show()

# %%
output2 = cv.GaussianBlur(gray_image, (9, 9), 5)
plt.imshow(output2)
plt.show()
